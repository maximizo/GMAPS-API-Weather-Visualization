# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# OpenWeatherMap API Key
weather_api_key = "YOUR KEY HERE!"

# Google API Key
g_key = "YOUR KEY HERE!"

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\izoto\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\izoto\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

#Import API key
from config import api_key

#Import citipy data
from citipy import citipy

#Create file output
output_data = "output_data/weatherpy.csv"

# %% [markdown]
# ## Generate Cities List

# %%
#Generate city data based on random coordinates and different query times

#Make lists for latitudes, longitudes and cities
lat_long = []
cities = []

#Crate random latitude and longitude coordinates
lat = np.random.uniform(-90,  90, 1500)
long = np.random.uniform(-180, 180, 1500)
lat_long = zip(lat, long)

#Call out city closest to each point on the list
for lat_long in lat_long: 
    city = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
    
    #Add city to list if it is unique
    if city not in cities:
        cities.append(city)
        
#print city list
print(cities)
# Out:
# ['nizhneangarsk', 'boatlaname', 'misratah', 'coquimbo', 'sur', 'taolanaro', 'belushya guba', 'hermanus', 'atuona', 'usinsk', 'sinkat', 'kapaa', 'arraial do cabo', 'hualmay', 'ahipara', 'sitka', 'margate', 'port-gentil', 'puerto ayora', 'lewistown', 'hobart', 'provideniya', 'mataura', 'ushuaia', 'leh', 'sol-iletsk', 'tiksi', 'palabuhanratu', 'kieta', 'illoqqortoormiut', 'santa maria', 'cayenne', 'te anau', 'barrow', 'nikolskoye', 'saskylakh', 'albany', 'san quintin', 'port macquarie', 'busselton', 'kidal', 'rikitea', 'punta arenas', 'avarua', 'bahia blanca', 'tsabong', 'souillac', 'chokurdakh', 'clyde river', 'yellowknife', 'drahovo', 'saleaula', 'opuwo', 'dikson', 'cape town', 'kununurra', 'san patricio', 'nobeoka', 'kaitangata', 'georgetown', 'ancud', 'singaraja', 'leningradskiy', 'mount darwin', 'bredasdorp', 'jamestown', 'cidreira', 'guasdualito', 'port blair', 'impfondo', 'upernavik', 'tavatuy', 'saint george', 'sept-iles', 'bethel', 'ilulissat', 'puerto baquerizo moreno', 'celestun', 'carnarvon', 'east london', 'mar del plata', 'setermoen', 'hilo', 'santa cruz del sur', 'bengkulu', 'comodoro rivadavia', 'ponta do sol', 'henties bay', 'aguimes', 'barentsburg', 'baghdad', 'sentyabrskiy', 'antofagasta', 'saint-augustin', 'guapi', 'vaini', 'vestmanna', 'villazon', 'ilhabela', 'mys shmidta', 'kuche', 'the pas', 'cap-aux-meules', 'hithadhoo', 'port keats', 'arman', 'samusu', 'new norfolk', 'severo-kurilsk', 'ardrishaig', 'khonuu', 'luderitz', 'mahebourg', 'saint-philippe', 'codrington', 'bluff', 'walvis bay', 'tigzirt', 'tabiauea', 'karamea', 'ngukurr', 'rabo de peixe', 'nizhneyansk', 'los llanos de aridane', 'tsihombe', 'butaritari', 'whitehorse', 'tuktoyaktuk', 'arona', 'lebu', 'am timan', 'bonthe', 'dergachi', 'saldanha', 'honningsvag', 'barbar', 'castro', 'salinopolis', 'longyearbyen', 'noumea', 'alofi', 'heilbron', 'kapit', 'isangel', 'monkey bay', 'killorglin', 'port elizabeth', 'tougan', 'thompson', 'sao filipe', 'klaksvik', 'russell', 'kangaba', 'cabo san lucas', 'butembo', 'talnakh', 'hoa binh', 'roebourne', 'szczecinek', 'sistranda', 'longonjo', 'jiujiang', 'norman wells', 'oudtshoorn', 'iqaluit', 'vaitupu', 'wilmington', 'ossora', 'jieshi', 'kodiak', 'faanui', 'longuenesse', 'menongue', 'ostrovnoy', 'nuuk', 'basco', 'bilibino', 'torbay', 'kavaratti', 'kavieng', 'chuguyevka', 'kusk', 'esperance', 'gangotri', 'saint-joseph', 'varhaug', 'buala', 'krasnoselkup', 'victoria', 'pacific grove', 'roald', 'sao joao da barra', 'timbo', 'ribeira grande', 'sioux lookout', 'alta floresta', 'port alfred', 'kulhudhuffushi', 'tilichiki', 'khatanga', 'qaqortoq', 'hirara', 'hasaki', 'karasjok', 'vysotskoye', 'mangan', 'khandyga', 'manggar', 'qaanaaq', 'dzhusaly', 'ucluelet', 'oranjemund', 'broken hill', 'airai', 'yakima', 'nexo', 'marsh harbour', 'ceres', 'kahului', 'san borja', 'guerrero negro', 'grand-santi', 'bathsheba', 'belmonte', 'cherskiy', 'nizhniy ingash', 'mokshan', 'tasiilaq', 'acapulco', 'sawtell', 'bandipur', 'sung noen', 'chuy', 'imbituba', 'slantsy', 'kattivakkam', 'malkangiri', 'suntar', 'praia', 'salalah', 'olafsvik', 'bambanglipuro', 'warmbad', 'san carlos de bariloche', 'salamina', 'bokoro', 'nam tha', 'padang', 'pinhao', 'nanortalik', 'san vicente', 'gat', 'kakinada', 'dingle', 'ko samui', 'brae', 'karaul', 'lawton', 'salta', 'nemuro', 'monrovia', 'hare bay', 'sakakah', 'geraldton', 'westport', 'kautokeino', 'lagoa', 'mananjary', 'toora-khem', 'pitimbu', 'cockburn harbour', 'mokhotlong', 'knysna', 'hwange', 'cuautepec', 'goderich', 'skjaerhollen', 'williston', 'la palma', 'louisbourg', 'denizli', 'korla', 'vasai', 'jadu', 'tete', 'kruisfontein', 'hofn', 'elat', 'birao', 'calama', 'vangaindrano', 'moron', 'french harbor', 'koumac', 'victor harbor', 'grand river south east', 'mayo', 'lingao', 'adrar', 'santa ana', 'chara', 'maloshuyka', 'cotonou', 'kokuy', 'mount isa', 'tuscaloosa', 'yar-sale', 'mtwara', 'hammerfest', 'maues', 'mikhaylovskoye', 'melo', 'tongren', 'faya', 'wufeng', 'boguchany', 'sosnovo-ozerskoye', 'ta ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Create a dataframe to store the data
city_weather = pd.DataFrame({'City': cities, 'Cloudiness': "", 'Date': "",
                            'Humidity': "", 'Lat': "", 'Lng': "", 'Max Temp': "", 'Windspeed': ""})

#Preview the dataframe
city_weather.head()
# Out:
#             City Cloudiness Date Humidity Lat Lng Max Temp Windspeed
# 0  nizhneangarsk
# 1     boatlaname
# 2       misratah
# 3       coquimbo
# 4            sur

# %%
#Variables to keep track of response number
record_num = 1
record_set = 1

#Set base URL
base_url = 'http://api.openweathermap.org/data/2.5/weather?q='


#Run API call for each city on the list
print('''
Beginning Data Retrieval
-----------------------------''')
for index, row in city_weather.iterrows(): 
    
    #Build new url for each city within the API call
    query_url = base_url + row['City'] + ',' + '&APPID=' + api_key
    
    #API call response
    response = requests.get(query_url).json()
    
    #If city is not found in the API call
    try: 
        #Message to alert the user that the data is being retrieved
        print(f'Processing Record {record_num} of Set {record_set} | {response["name"]}')
        
        #Input data into the dataframe
        city_weather.loc[index, 'Cloudiness'] = response['clouds']['all']
        city_weather.loc[index, 'Date'] = response['dt']
        city_weather.loc[index, 'Humidity'] = response['main']['humidity']
        city_weather.loc[index, 'Lat'] = response['coord']['lat']
        city_weather.loc[index, 'Lng'] = response['coord']['lon']
        city_weather.loc[index, 'Max Temp'] = response['main']['temp_max']
        city_weather.loc[index, 'Windspeed'] = response['wind']['speed']
        
        #Increase the record count
        record_num += 1
        
    except (KeyError, IndexError):
        print('City not found. Skipping...')
    
    #Set limits to API call
    if record_num == 51:
        record_set += 1
        record_num = 1
        time.sleep(60)
        
print('''
-------------------------------
Data Retrieval Complete
-------------------------------''')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Nizhneangarsk
# City not found. Skipping...
# Processing Record 2 of Set 1 | Misratah
# Processing Record 3 of Set 1 | Coquimbo
# Processing Record 4 of Set 1 | Sur
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 1 | Hermanus
# Processing Record 6 of Set 1 | Atuona
# Processing Record 7 of Set 1 | Usinsk
# City not found. Skipping...
# Processing Record 8 of Set 1 | Kapaa
# Processing Record 9 of Set 1 | Arraial do Cabo
# Processing Record 10 of Set 1 | Hualmay
# Processing Record 11 of Set 1 | Ahipara
# Processing Record 12 of Set 1 | Sitka
# Processing Record 13 of Set 1 | Margate
# Processing Record 14 of Set 1 | Port-Gentil
# Processing Record 15 of Set 1 | Puerto Ayora
# Processing Record 16 of Set 1 | Lewistown
# Processing Record 17 of Set 1 | Hobart
# Processing Record 18 of Set 1 | Provideniya
# City not found. Skipping...
# Processing Record 19 of Set 1 | Ushuaia
# Processing Record 20 of Set 1 | Leh
# Processing Record 21 of Set 1 | Sol'-Iletsk
# Processing Record 22 of Set 1 | Tiksi
# City not found. Skipping...
# Processing Record 23 of Set 1 | Kieta
# City not found. Skipping...
# Processing Record 24 of Set 1 | Santa Maria
# Processing Record 25 of Set 1 | Cayenne
# Processing Record 26 of Set 1 | Te Anau
# Processing Record 27 of Set 1 | Barrow
# City not found. Skipping...
# Processing Record 28 of Set 1 | Saskylakh
# Processing Record 29 of Set 1 | Albany
# Processing Record 30 of Set 1 | San Quintín
# Processing Record 31 of Set 1 | Port Macquarie
# Processing Record 32 of Set 1 | Busselton
# Processing Record 33 of Set 1 | Kidal
# Processing Record 34 of Set 1 | Rikitea
# Processing Record 35 of Set 1 | Punta Arenas
# Processing Record 36 of Set 1 | Avarua
# Processing Record 37 of Set 1 | Bahía Blanca
# City not found. Skipping...
# Processing Record 38 of Set 1 | Souillac
# Processing Record 39 of Set 1 | Chokurdakh
# Processing Record 16 of Set 4 | Timbó
# Processing Record 17 of Set 4 | Ribeira Grande
# Processing Record 18 of Set 4 | Sioux Lookout
# Processing Record 19 of Set 4 | Alta Floresta
# Processing Record 20 of Set 4 | Port Alfred
# Processing Record 21 of Set 4 | Kulhudhuffushi
# Processing Record 22 of Set 4 | Tilichiki
# Processing Record 23 of Set 4 | Khatanga
# Processing Record 24 of Set 4 | Qaqortoq
# Processing Record 25 of Set 4 | Hirara
# Processing Record 26 of Set 4 | Hasaki
# Processing Record 27 of Set 4 | Karasjok
# Processing Record 28 of Set 4 | Vysotskoye
# Processing Record 29 of Set 4 | Mangan
# Processing Record 30 of Set 4 | Khandyga
# Processing Record 31 of Set 4 | Manggar
# Processing Record 32 of Set 4 | Qaanaaq
# City not found. Skipping...
# Processing Record 33 of Set 4 | Ucluelet
# Processing Record 34 of Set 4 | Oranjemund
# Processing Record 35 of Set 4 | Broken Hill
# City not found. Skipping...
# Processing Record 36 of Set 4 | Yakima
# Processing Record 37 of Set 4 | Nexø
# Processing Record 38 of Set 4 | Marsh Harbour
# Processing Record 39 of Set 4 | Ceres
# Processing Record 40 of Set 4 | Kahului
# Processing Record 41 of Set 4 | San Borja
# Processing Record 42 of Set 4 | Guerrero Negro
# Processing Record 43 of Set 4 | Grand-Santi
# Processing Record 44 of Set 4 | Bathsheba
# Processing Record 45 of Set 4 | Belmonte
# Processing Record 46 of Set 4 | Cherskiy
# Processing Record 47 of Set 4 | Nizhniy Ingash
# Processing Record 48 of Set 4 | Mokshan
# Processing Record 49 of Set 4 | Tasiilaq
# Processing Record 50 of Set 4 | Acapulco de Juárez
# Processing Record 1 of Set 5 | Sawtell
# Processing Record 2 of Set 5 | Bandi̇̄pur
# Processing Record 3 of Set 5 | Sung Noen
# Processing Record 4 of Set 5 | Chui
# Processing Record 5 of Set 5 | Imbituba
# Processing Record 6 of Set 5 | Slantsy
# Processing Record 7 of Set 5 | Kattivākkam
# Processing Record 8 of Set 5 | Malakanagiri
# Processing Record 9 of Set 5 | Suntar
# Processing Record 10 of Set 5 | Praia
# Processing Record 11 of Set 5 | Salalah
# Processing Record 12 of Set 5 | Olafsvik
# Processing Record 13 of Set 5 | Bambanglipuro
# Processing Record 14 of Set 5 | Warmbad
# Processing Record 15 of Set 5 | Bariloche
# Processing Record 16 of Set 5 | Salamina
# Processing Record 17 of Set 5 | Bokoro
# City not found. Skipping...
# Processing Record 18 of Set 5 | Padang
# Processing Record 19 of Set 5 | Pinhão
# Processing Record 20 of Set 5 | Nanortalik
# Processing Record 21 of Set 5 | San Vicente
# Processing Record 22 of Set 5 | Kiryat Gat
# Processing Record 23 of Set 5 | Kākināda
# Processing Record 24 of Set 5 | Dingle
# Processing Record 25 of Set 5 | Ko Samui
# Processing Record 26 of Set 5 | Brae
# City not found. Skipping...
# Processing Record 27 of Set 5 | Lawton
# Processing Record 28 of Set 5 | Salta
# Processing Record 29 of Set 5 | Nemuro
# Processing Record 30 of Set 5 | Monrovia
# Processing Record 31 of Set 5 | Hare Bay
# Processing Record 32 of Set 5 | Sakakah
# Processing Record 33 of Set 5 | Geraldton
# Processing Record 34 of Set 5 | Westport
# Processing Record 35 of Set 5 | Kautokeino
# Processing Record 36 of Set 5 | Lagoa
# Processing Record 37 of Set 5 | Mananjary
# Processing Record 38 of Set 5 | Toora-Khem
# Processing Record 39 of Set 5 | Pitimbu
# City not found. Skipping...
# Processing Record 40 of Set 5 | Mokhotlong
# Processing Record 41 of Set 5 | Knysna
# Processing Record 42 of Set 5 | Hwange
# Processing Record 43 of Set 5 | Cuautepec
# Processing Record 44 of Set 5 | Goderich
# City not found. Skipping...
# Processing Record 45 of Set 5 | Williston
# Processing Record 46 of Set 5 | La Palma
# City not found. Skipping...
# Processing Record 47 of Set 5 | Denizli Province
# Processing Record 48 of Set 5 | Korla
# Processing Record 49 of Set 5 | Vasai
# City not found. Skipping...
# Processing Record 50 of Set 5 | Tete
# Processing Record 1 of Set 6 | Kruisfontein
# Processing Record 2 of Set 6 | Hofn
# Processing Record 3 of Set 6 | Eilat
# Processing Record 4 of Set 6 | Birao
# Processing Record 5 of Set 6 | Calama
# Processing Record 6 of Set 6 | Vangaindrano
# Processing Record 7 of Set 6 | Morón
# Processing Record 8 of Set 6 | French Harbor
# Processing Record 9 of Set 6 | Koumac
# Processing Record 10 of Set 6 | Victor Harbor
# City not found. Skipping...
# Processing Record 11 of Set 6 | Mayo
# City not found. Skipping...
# Processing Record 12 of Set 6 | Adrar
# Processing Record 13 of Set 6 | Santa Ana
# Processing Record 14 of Set 6 | Chara
# City not found. Skipping...
# Processing Record 15 of Set 6 | Cotonou
# Processing Record 16 of Set 6 | Kokuy
# Processing Record 17 of Set 6 | Mount Isa
# Processing Record 18 of Set 6 | Tuscaloosa
# Processing Record 19 of Set 6 | Yar-Sale
# Processing Record 20 of Set 6 | Mtwara
# Processing Record 21 of Set 6 | Hammerfest
# Processing Record 22 of Set 6 | Maués
# Processing Record 23 of Set 6 | Mikhaylovskoye
# Processing Record 24 of Set 6 | Melo
# Processing Record 25 of Set 6 | Tongren
# City not found. Skipping...
# Processing Record 26 of Set 6 | Wufeng
# Processing Record 27 of Set 6 | Boguchany
# Processing Record 28 of Set 6 | Sosnovo-Ozerskoye
# Processing Record 29 of Set 6 | Taltal
# Processing Record 30 of Set 6 | Mackenzie
# Processing Record 31 of Set 6 | Fortuna
# Processing Record 32 of Set 6 | Najrān
# Processing Record 33 of Set 6 | Vanimo
# Processing Record 34 of Set 6 | Bree
# Processing Record 35 of Set 6 | Harper
# Processing Record 36 of Set 6 | Mahibadhoo
# Processing Record 37 of Set 6 | Canutama
# Processing Record 38 of Set 6 | Lata
# Processing Record 39 of Set 6 | Dalvik
# Processing Record 40 of Set 6 | Singapore
# Processing Record 41 of Set 6 | Havre-St-Pierre
# Processing Record 42 of Set 6 | Quatre Cocos
# Processing Record 43 of Set 6 | Izumo
# Processing Record 44 of Set 6 | Houston
# Processing Record 45 of Set 6 | Plettenberg Bay
# Processing Record 46 of Set 6 | Yuzhno-Kurilsk
# Processing Record 47 of Set 6 | Kingman
# Processing Record 48 of Set 6 | Nacala
# Processing Record 49 of Set 6 | Rawson
# Processing Record 50 of Set 6 | Vardø
# Processing Record 1 of Set 7 | Touros
# Processing Record 2 of Set 7 | Songyuan
# Processing Record 3 of Set 7 | Syamzha
# Processing Record 4 of Set 7 | De Aar
# Processing Record 5 of Set 7 | Redmond
# Processing Record 6 of Set 7 | Fukuechō
# Processing Record 7 of Set 7 | Saurimo
# Processing Record 8 of Set 7 | Matara
# Processing Record 9 of Set 7 | Lamar
# City not found. Skipping...
# Processing Record 10 of Set 7 | Yanaul
# Processing Record 11 of Set 7 | Lufilufi
# Processing Record 12 of Set 7 | Tura
# Processing Record 13 of Set 7 | Sigli
# Processing Record 14 of Set 7 | Petropavlovsk-Kamchatskiy
# Processing Record 15 of Set 7 | Miguel Alves
# Processing Record 16 of Set 7 | Fort Nelson
# Processing Record 17 of Set 7 | Half Moon Bay
# Processing Record 18 of Set 7 | Oyama
# Processing Record 19 of Set 7 | Maamba
# Processing Record 20 of Set 7 | Fort-Shevchenko
# Processing Record 21 of Set 7 | Miguel Hidalgo
# Processing Record 22 of Set 7 | Gigmoto
# Processing Record 23 of Set 7 | Waipawa
# Processing Record 24 of Set 7 | Santiago
# Processing Record 25 of Set 7 | Vaitape
# Processing Record 26 of Set 7 | Acandí
# Processing Record 27 of Set 7 | Bubaque
# Processing Record 28 of Set 7 | Derzhavīnsk
# Processing Record 29 of Set 7 | Kondinskoye
# Processing Record 30 of Set 7 | Ust-Tsilma
# Processing Record 31 of Set 7 | São Gabriel
# Processing Record 32 of Set 7 | Bambous Virieux
# Processing Record 33 of Set 7 | Muisne
# Processing Record 34 of Set 7 | Abalak
# Processing Record 35 of Set 7 | Turmalina
# City not found. Skipping...
# Processing Record 36 of Set 7 | Katsuura
# Processing Record 37 of Set 7 | Moa
# Processing Record 38 of Set 7 | Arauca
# Processing Record 39 of Set 7 | Bandarbeyla
# Processing Record 40 of Set 7 | Brigantine
# Processing Record 41 of Set 7 | Mujiayingzi
# Processing Record 42 of Set 7 | Narsaq
# Processing Record 43 of Set 7 | Chapais
# Processing Record 44 of Set 7 | Kaeo
# Processing Record 45 of Set 7 | Zhigansk
# Processing Record 46 of Set 7 | Šilalė
# Processing Record 47 of Set 7 | Payakumbuh
# Processing Record 48 of Set 7 | George
# City not found. Skipping...
# Processing Record 49 of Set 7 | Maceió
# Processing Record 50 of Set 7 | Wadi Maliz
# Processing Record 1 of Set 8 | Road Town
# Processing Record 2 of Set 8 | Mucuri
# Processing Record 3 of Set 8 | Pincher Creek
# Processing Record 4 of Set 8 | Manokwari
# Processing Record 5 of Set 8 | Southbridge
# Processing Record 6 of Set 8 | Port Hardy
# Processing Record 7 of Set 8 | Labuhan
# Processing Record 21 of Set 9 | Mayumba
# Processing Record 22 of Set 9 | Puerto Carreño
# Processing Record 23 of Set 9 | Iracoubo
# Processing Record 24 of Set 9 | Mandalī
# Processing Record 25 of Set 9 | Hambantota
# Processing Record 26 of Set 9 | Conceição do Araguaia
# Processing Record 27 of Set 9 | Kikwit
# Processing Record 28 of Set 9 | Goma
# Processing Record 29 of Set 9 | Musoma
# Processing Record 30 of Set 9 | Le Port
# Processing Record 31 of Set 9 | Grindavik
# Processing Record 32 of Set 9 | Gachsaran
# Processing Record 33 of Set 9 | Urdoma
# Processing Record 34 of Set 9 | Corrente
# Processing Record 35 of Set 9 | Oranjestad
# Processing Record 36 of Set 9 | Miranda de Ebro
# Processing Record 37 of Set 9 | Beloha
# City not found. Skipping...
# Processing Record 38 of Set 9 | Gallup
# City not found. Skipping...
# Processing Record 39 of Set 9 | Meulaboh
# Processing Record 40 of Set 9 | Puerto Madero
# Processing Record 41 of Set 9 | Ambunti
# Processing Record 42 of Set 9 | Pisco
# Processing Record 43 of Set 9 | Beringovskiy
# Processing Record 44 of Set 9 | Klimovo
# Processing Record 45 of Set 9 | Dakar
# Processing Record 46 of Set 9 | Manjacaze
# Processing Record 47 of Set 9 | Yangi Marg`ilon
# Processing Record 48 of Set 9 | Gamba
# Processing Record 49 of Set 9 | Yakeshi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 9 | Bara
# Processing Record 1 of Set 10 | Inhambane
# Processing Record 2 of Set 10 | Caravelas
# Processing Record 3 of Set 10 | Amantea
# City not found. Skipping...
# Processing Record 4 of Set 10 | Doka
# Processing Record 5 of Set 10 | Linares
# Processing Record 6 of Set 10 | Acopiara
# Processing Record 7 of Set 10 | Aykhal
# Processing Record 8 of Set 10 | Bulawayo
# City not found. Skipping...
# Processing Record 9 of Set 10 | Ust-Nera
# Processing Record 10 of Set 10 | Nelson Bay
# Processing Record 11 of Set 10 | Muzhi
# City not found. Skipping...
# Processing Record 12 of Set 10 | High Rock
# Processing Record 13 of Set 10 | Garut
# Processing Record 14 of Set 10 | Lucapa
# City not found. Skipping...
# Processing Record 15 of Set 10 | Suşehri
# Processing Record 16 of Set 10 | Batagay
# City not found. Skipping...
# Processing Record 17 of Set 10 | Conway
# Processing Record 18 of Set 10 | Lavrentiya
# Processing Record 19 of Set 10 | Kochi
# Processing Record 20 of Set 10 | Poum
# Processing Record 21 of Set 10 | Nome
# Processing Record 22 of Set 10 | Kendari
# Processing Record 23 of Set 10 | Amnat Charoen
# Processing Record 24 of Set 10 | Imeni Poliny Osipenko
# Processing Record 25 of Set 10 | Namalenga
# Processing Record 26 of Set 10 | Dhule
# Processing Record 27 of Set 10 | Balsas
# Processing Record 28 of Set 10 | Ambanja
# Processing Record 29 of Set 10 | Pokhara
# Processing Record 30 of Set 10 | Grande Prairie
# Processing Record 31 of Set 10 | Viedma
# Processing Record 32 of Set 10 | Malé
# City not found. Skipping...
# Processing Record 33 of Set 10 | Novopokrovka
# Processing Record 34 of Set 10 | Nyurba
# Processing Record 35 of Set 10 | Tokur
# Processing Record 36 of Set 10 | Topchikha
# Processing Record 37 of Set 10 | Ciudad Bolivar
# Processing Record 38 of Set 10 | Ouésso
# Processing Record 39 of Set 10 | Mossamedes
# Processing Record 40 of Set 10 | Nagīna
# Processing Record 41 of Set 10 | Maragogi
# Processing Record 42 of Set 10 | Manadhoo
# Processing Record 43 of Set 10 | Northam
# Processing Record 44 of Set 10 | Cap Malheureux
# Processing Record 45 of Set 10 | Santarém
# Processing Record 46 of Set 10 | Alice Springs
# Processing Record 47 of Set 10 | Mozarlândia
# Processing Record 48 of Set 10 | Teya
# City not found. Skipping...
# Processing Record 49 of Set 10 | Tugbong
# Processing Record 50 of Set 10 | Aromashevo
# Processing Record 1 of Set 11 | Philadelphia
# Processing Record 2 of Set 11 | Sungai Penuh
# Processing Record 3 of Set 11 | Carnot
# Processing Record 4 of Set 11 | Taseyevo
# Processing Record 5 of Set 11 | Nakhon Thai
# City not found. Skipping...
# Processing Record 6 of Set 11 | Wairoa
# Processing Record 7 of Set 11 | Moranbah
# Processing Record 8 of Set 11 | Nurota
# Processing Record 9 of Set 11 | Uttaradit
# Processing Record 10 of Set 11 | Paciran
# Processing Record 11 of Set 11 | Nishihara
# Processing Record 12 of Set 11 | Aktas
# Processing Record 13 of Set 11 | Zakamensk
# Processing Record 14 of Set 11 | Panzhihua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 11 | Nortelândia
# Processing Record 16 of Set 11 | Luanda
# Processing Record 17 of Set 11 | Carora
# Processing Record 18 of Set 11 | Ilave
# Processing Record 19 of Set 11 | Solhan
# Processing Record 20 of Set 11 | Warrnambool
# City not found. Skipping...
# Processing Record 21 of Set 11 | Znamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 11 | Majene
# Processing Record 23 of Set 11 | Benin
# Processing Record 24 of Set 11 | Americus
# Processing Record 25 of Set 11 | Eureka
# Processing Record 26 of Set 11 | Unión Hidalgo
# Processing Record 27 of Set 11 | Vanavara
# Processing Record 28 of Set 11 | Mountain Home
# Processing Record 29 of Set 11 | Labuan
# Processing Record 30 of Set 11 | Yeppoon
# Processing Record 31 of Set 11 | Aklavik
# Processing Record 32 of Set 11 | Constitución
# Processing Record 33 of Set 11 | Kutum
# Processing Record 34 of Set 11 | Teahupoo
# Processing Record 35 of Set 11 | Jertih
# City not found. Skipping...
# Processing Record 36 of Set 11 | Istok
# Processing Record 37 of Set 11 | Muslyumovo
# Processing Record 38 of Set 11 | Alvand
# Processing Record 39 of Set 11 | College
# Processing Record 40 of Set 11 | Turan
# Processing Record 41 of Set 11 | Gravdal
# City not found. Skipping...
# Processing Record 42 of Set 11 | Skjervøy
# Processing Record 43 of Set 11 | Esim
# Processing Record 44 of Set 11 | The Valley
# Processing Record 45 of Set 11 | San Ramon
#
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Clean dataframe 
city_weather['Max Temp'] = city_weather['Max Temp'].replace('', np.nan)
city_weather = city_weather.dropna()

#Save dataframe
city_weather.to_csv("output_data/CityWeatherData.csv", index = False, header = True)

#Preview 
city_weather.head()
# Out:
#             City Cloudiness        Date Humidity    Lat     Lng  Max Temp  \
# 0  nizhneangarsk         33  1601000654       61  55.78  109.55    283.80
# 2       misratah          0  1601000654       58  32.38   15.09    300.91
# 3       coquimbo         90  1601000654       82 -29.95  -71.34    286.15
# 4            sur          6  1601000655       55  22.57   59.53    299.93
# 7       hermanus         11  1601000655       81 -34.42   19.23    283.71
#
#   Windspeed
# 0      1.91
# 2      3.54
# 3       1.5
# 4      0.74
# 7      7.56

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Check for maximum humidity
max(city_weather['Humidity'])

#Skip this step becaue there are no cities that have humidity > 100%
# Out:
# 100

# %%
#  Get the indices of cities that have humidity over 100%.
#Skip this step

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#Skip this step

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_weather['Lat'], city_weather['Max Temp'], edgecolors = 'black')
plt.title('City Latitude vs. Max Temperature (09/20)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid(b = False, which = 'major', axis = 'both', linestyle = '-', color = 'grey')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_weather['Lat'], city_weather['Humidity'], edgecolors = 'black')
plt.title('City Latitude vs. Humidity (09/20)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(b = False, which = 'major', axis = 'both', linestyle = '-', color = 'grey')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_weather['Lat'], city_weather['Cloudiness'], edgecolors = 'black')
plt.title('City Latitude vs. Cloudiness (09/20)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(b = False, which = 'major', axis = 'both', linestyle = '-', color = 'grey')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_weather['Lat'], city_weather['Windspeed'], edgecolors = 'black')
plt.title('City Latitude vs. Wind Speed (09/20)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(b = False, which = 'major', axis = 'both', linestyle = '-', color = 'grey')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create linear regression for max temp vs. latitude in Northern Hemisphere
#Define Northern Hemisphere
northern = city_weather.loc[pd.to_numeric(city_weather['Lat']).astype(float) > 0, :]

#Create Plot
x_values = pd.to_numeric(northern['Lat']).astype(float)
y_values = pd.to_numeric(northern['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7622495123917162

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create liner regression for Southern Hemisphere max temp vs. latitude
#Define Southern Hemisphere
southern = city_weather.loc[pd.to_numeric(city_weather['Lat']).astype(float) > 0, :]
x_values = pd.to_numeric(southern['Lat']).astype(float)
y_values = pd.to_numeric(southern['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.7622495123917162

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create linear regression for Northern Hemisphere humidity vs. latitude
x_values = pd.to_numeric(northern['Lat']).astype(float)
y_values = pd.to_numeric(northern['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0006440412949040732

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Create linear regression for Southern Hemisphere humidity vs. latitude
x_values = pd.to_numeric(southern['Lat']).astype(float)
y_values = pd.to_numeric(southern['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0006440412949040732

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create linear regression for Northern Hemisphere Cloudiness vs. latitude
x_values = pd.to_numeric(northern['Lat']).astype(float)
y_values = pd.to_numeric(northern['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.006302272265549153

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Create linear regression for Southern Hemisphere cloudiness vs. latitude
x_values = pd.to_numeric(southern['Lat']).astype(float)
y_values = pd.to_numeric(southern['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0006440412949040732

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create linear regression for Northern Hemisphere wind speed vs. latitude
x_values = pd.to_numeric(northern['Lat']).astype(float)
y_values = pd.to_numeric(northern['Windspeed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.09398924833640206

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Create linear regression for Southern Hemisphere wind speed vs. latitude
x_values = pd.to_numeric(southern['Lat']).astype(float)
y_values = pd.to_numeric(southern['Windspeed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.09398924833640206
